# %% [markdown]
# Project 1: Peer-graded Assignment

# %% [markdown]
# ## Introduction
# In this notebook, we summarize some of the key tools, libraries, and concepts used in Data Science.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - Numpy
# - Matplotlib
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
# | Tool            | Description                |
# |-----------------|----------------------------|
# | Jupyter Notebook| Interactive code environment|
# | RStudio         | IDE for R                  |
# | Apache Zeppelin | Data analytics notebook    |

# %% [markdown]
# ## Examples of Arithmetic Expressions
# Here are some examples of simple arithmetic expressions.

# %%
# Multiply and Add
(3 * 4) + 5

# %%
# Convert minutes to hours
minutes = 120
hours = minutes / 60
hours

# %% [markdown]
# ## Objectives
# - List popular languages for Data Science
# - List commonly used libraries
# - Introduce arithmetic operations
# - Create tables using markdown
# - Convert units using Python

# %% [markdown]
# ## Author
# Muya Liu
